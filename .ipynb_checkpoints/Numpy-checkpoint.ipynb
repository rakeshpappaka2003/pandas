# %%
import numpy as np

# %%
#np.array(elements)

# %%
import numpy as np
n1 = np.array([12,3,44,5,])
n1
# Out:
# array([12,  3, 44,  5])

# %%
zero_d=np.array(1)

# %%
zero_d
# Out:
# array(1)

# %%
zero_d.ndim
# Out:
# 0

# %%
one_d= np.array([1,2,3,4])

# %%
one_d
# Out:
# array([1, 2, 3, 4])

# %%
one_d.ndim
# Out:
# 1

# %%
n1=np.array(['chicken_burger','cheese_burger'])

# %%
n1
# Out:
# array(['chicken_burger', 'cheese_burger'], dtype='<U14')

# %%
two_d=np.array([[1,2,3,4],[6,7,8,9]])

# %%
two_d.ndim
# Out:
# 2

# %%
two_d.size
# Out:
# 8

# %%
n1 = np.array([[[1,2,3,4]]])

# %%
n1.ndim
# Out:
# 3

# %%
n1.size
# Out:
# 4

# %%
n1=np.array([[['chicken_burger','cheese_burger']]])

# %%
n1.ndim
# Out:
# 3

# %%
n1
# Out:
# array([[['chicken_burger', 'cheese_burger']]], dtype='<U14')

# %%
n2=np.array([[1,2,3,4],[5,6,7,8]])

# %%
n2.shape
# Out:
# (1, 1, 4, 4)

# %%
n2=np.array([[[[1,2,3,4],[5,6,7,8],
 [12,13,14,15],[16,17,18,19]]]])

# %%
n2
# Out:
# array([[[[ 1,  2,  3,  4],
#          [ 5,  6,  7,  8],
#          [12, 13, 14, 15],
#          [16, 17, 18, 19]]]])

# %%
n2.ndim
# Out:
# 4

# %%
n2.size
# Out:
# 16

# %%
n2[0]
# Out:
# array([[[ 1,  2,  3,  4],
#         [ 5,  6,  7,  8]],
#
#        [[12, 13, 14, 15],
#         [16, 17, 18, 19]]])

# %%
dict1={'a':1,'b':2}

# %%
for i in dict1:
    print(i)
# Out:
# a
# b

# %%
import numpy as np
n1=np.array([[['a','b','c'],['a','b','c'],['a','b','c']]])

# %%
n1
# Out:
# array([[['a', 'b', 'c'],
#         ['a', 'b', 'c'],
#         ['a', 'b', 'c']]], dtype='<U1')

# %%
n1[0,2,2]
# Out:
# np.str_('c')

# %%
n1[0,2,1]
# Out:
# np.str_('b')

# %%
n1[0,2,0]
# Out:
# np.str_('a')

# %%
n1[0,1,1]
# Out:
# np.str_('b')

# %%
n1[0,1,2]
# Out:
# np.str_('c')

# %%
n1=np.array([[['a','b','c'],['a','b','c'],['a','b','c']]])
np.insert(n1,8,'r')
# Out:
# array(['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'r', 'c'], dtype='<U1')

# %%
n1=np.array([[['chicken_burger','cheese_burger']]])
np.insert(n1,1,'rakesh',axis=1)
# Out:
# array([[['chicken_burger', 'cheese_burger'],
#         ['rakesh', 'rakesh']]], dtype='<U14')

# %%
n1=np.array([[['chicken_burger','cheese_burger']]])
np.insert(n1,0,'rakesh',axis=1)
# Out:
# array([[['rakesh', 'rakesh'],
#         ['chicken_burger', 'cheese_burger']]], dtype='<U14')

# %%
np.append(n1,'rakesh')
# Out:
# array(['chicken_burger', 'cheese_burger', 'rakesh'], dtype='<U14')

# %%
np.add(n1,'lokesh')
# Out:
# array([[['chicken_burgerlokesh', 'cheese_burgerlokesh']]], dtype='<U20')

# %%
n1.shape
# Out:
# (1, 1, 2)

# %%
n2.shape
# Out:
# (1, 1, 4, 4)

# %%
n1=np.array([['chicken_burger','cheese_burger']])
n1
# Out:
# array([['chicken_burger', 'cheese_burger']], dtype='<U14')

# %%
n1.shape
# Out:
# (1, 2)

# %%
np.delete(n1,0)
# Out:
# array(['cheese_burger'], dtype='<U14')
